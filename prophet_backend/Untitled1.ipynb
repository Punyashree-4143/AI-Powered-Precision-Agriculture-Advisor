# %%
pip install pandas numpy matplotlib scikit-learn xgboost prophet joblib fastapi uvicorn
# Out:
# Requirement already satisfied: pandas in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (3.10.7)
# Requirement already satisfied: scikit-learn in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (1.7.2)
# Requirement already satisfied: xgboost in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (3.1.1)
# Requirement already satisfied: prophet in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (1.2.1)
# Requirement already satisfied: joblib in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (1.5.2)
# Requirement already satisfied: fastapi in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (0.121.2)
# Requirement already satisfied: uvicorn in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (0.38.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prophet) (1.3.0)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prophet) (0.85)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from fastapi) (0.49.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from fastapi) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ipywidgets
# !pip install jupyter
# !pip install plotly
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#      ------------------------------------ 139.8/139.8 kB 127.7 kB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.3 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipywidgets) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 2.7 MB/s eta 0:00:00
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#      -------------------------------------- 914.9/914.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama>=0.4.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\punya\\agriculture-advisor\\prophet_backend\\prophet_model_env\\share\\jupyter\\labextensions\\@jupyter-widgets\\jupyterlab-manager\\static\\vendors-node_modules_d3-color_src_color_js-node_modules_d3-format_src_defaultLocale_js-node_m-09b215.2643c43f22ad111f4f82.js'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ^C
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook
#   Downloading notebook-7.4.7-py3-none-any.whl (14.3 MB)
#      ---------------------------------------- 14.3/14.3 MB 2.1 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      -------------------------------------- 258.5/258.5 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyter) (7.1.0)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Collecting jupyterlab
#   Downloading jupyterlab-4.4.10-py3-none-any.whl (12.3 MB)
#      ---------------------------------------- 12.3/12.3 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyter-console->jupyter) (3.0.52)
# Requirement already satisfied: pygments in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyter-console->jupyter) (2.19.2)
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting httpx<1,>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting jinja2>=3.0.3
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#      ---------------------------------------- 76.7/76.7 kB 1.4 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.17.0-py3-none-any.whl (388 kB)
#      -------------------------------------- 388.2/388.2 kB 2.0 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#      ---------------------------------------- 59.8/59.8 kB 1.6 MB/s eta 0:00:00
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyterlab->jupyter) (65.5.0)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.4/106.4 kB 3.1 MB/s eta 0:00:00
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
#      -------------------------------------- 164.4/164.4 kB 3.3 MB/s eta 0:00:00
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting markupsafe>=2.0
#   Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.4-py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.5/53.5 kB 2.7 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting nbformat>=5.7
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: anyio in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Collecting certifi
#   Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#      -------------------------------------- 159.4/159.4 kB 4.8 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: idna in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.0)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.23.1-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.1/61.1 kB 3.2 MB/s eta 0:00:00
# Collecting pywinpty>=2.0.1
#   Downloading pywinpty-3.0.2-cp311-cp311-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 1.1 MB/s eta 0:00:00
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.6/82.6 kB 2.3 MB/s eta 0:00:00
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ---------------------------------------- 10.2/10.2 MB 2.4 MB/s eta 0:00:00
# Collecting json5>=0.9.0
#   Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      -------------------------------------- 90.0/90.0 kB 725.5 kB/s eta 0:00:00
# Collecting requests>=2.31
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.14)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl (31 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.6/67.6 kB 1.8 MB/s eta 0:00:00
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.29.0-cp311-cp311-win_amd64.whl (235 kB)
#      -------------------------------------- 235.7/235.7 kB 7.3 MB/s eta 0:00:00
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.3
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#      ------------------------------------ 158.8/158.8 kB 560.5 kB/s eta 0:00:00
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter) (1.17.0)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting rfc3987-syntax>=1.1.0
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
#      -------------------------------------- 182.8/182.8 kB 1.8 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.23-py3-none-any.whl (118 kB)
#      -------------------------------------- 118.1/118.1 kB 7.2 MB/s eta 0:00:00
# Collecting lark>=1.2.2
#   Downloading lark-1.3.1-py3-none-any.whl (113 kB)
#      -------------------------------------- 113.2/113.2 kB 2.2 MB/s eta 0:00:00
# Collecting arrow>=0.15.0
#   Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
#      ---------------------------------------- 68.8/68.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: tzdata in c:\users\punya\agriculture-advisor\prophet_backend\prophet_model_env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.2)
# Installing collected packages: webencodings, fastjsonschema, websocket-client, webcolors, urllib3, uri-template, tinycss2, soupsieve, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, mistune, markupsafe, lark, jupyterlab-pygments, jsonpointer, json5, fqdn, defusedxml, charset_normalizer, certifi, bleach, babel, attrs, async-lru, terminado, rfc3987-syntax, requests, referencing, jinja2, httpcore, cffi, beautifulsoup4, arrow, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter

# %%
# !python -m pip install --upgrade pip

# %%
import glob

CSV_GLOB = r"C:\Users\punya\Downloads\market\csv\*.csv"

all_files = glob.glob(CSV_GLOB)
print("Files found:", len(all_files))
print(all_files[:5])   # show first 5 files

# %%
import pandas as pd
import glob

CSV_GLOB = r"C:\Users\punya\Downloads\market\csv\*.csv"

df_list = []

for f in glob.glob(CSV_GLOB):
    print("Loading:", f)
    tmp = pd.read_csv(f)

    # Filter Karnataka while reading  (memory safe!)
    tmp = tmp[tmp['State'] == "Karnataka"]

    df_list.append(tmp)

df_kar = pd.concat(df_list, ignore_index=True)
print("Karnataka rows:", len(df_kar))
df_kar.head()

# %%
import pandas as pd
import numpy as np
import os
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib
from datetime import timedelta

# Path to folder that contains yearly CSVs
DATA_FOLDER = r"C:\Users\punya\Downloads\market\csv"

# Load all CSVs
all_files = [os.path.join(DATA_FOLDER, f) for f in os.listdir(DATA_FOLDER) if f.endswith(".csv")]
print("Found files:", len(all_files))

df_list = []
for f in sorted(all_files):
    print("Loading:", f)
    df_list.append(pd.read_csv(f))

df = pd.concat(df_list, ignore_index=True)
print("Total Rows:", len(df))
